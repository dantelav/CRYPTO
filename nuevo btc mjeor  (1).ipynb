# %%
import pandas as pd 
import numpy as np
file_list = ['1INCH', 'AAVE', 'ABBC', 'ACH', 'ADA', 'ALGO', 'ANKR', 'APE', 'AR', 'ASTR', 'ATOM', 'AUDIO', 'AVAX', 'AXS', 'BAT', 'BCH', 'BICO', 'BNB', 'BNX', 'BORA', 'BSV', 'BTC', 'BTG', 'BTT', 'BUSD', 'CAKE', 'CELO', 'CELR', 'CFX', 'CHZ', 'CKB', 'COMP', 'CRO', 'CRV', 'CSPR', 'CTSI', 'CVX', 'DAI', 'DAO', 'DASH', 'DCR', 'DGB', 'DOGE', 'DOT', 'DYDX', 'EGLD', 'ELF', 'ELON', 'ENJ', 'ENS', 'EOS', 'ETC', 'ETH', 'ETHW', 'EVER', 'FET', 'FIL', 'FLOW', 'FLUX', 'FTM', 'FXS', 'GALA', 'GLM', 'GLMR', 'GMT', 'GNO', 'GRT', 'GT', 'GUSD', 'HBAR', 'HIVE', 'HNT', 'HOT', 'HT', 'ICP', 'ICX', 'ILV', 'IMX', 'INJ', 'IOST', 'IOTX', 'JOE', 'JST', 'KAVA', 'KCS', 'KDA', 'KLAY', 'KNC', 'KSM', 'LDO', 'LEO', 'LINK', 'LPT', 'LQTY', 'LRC', 'LTC', 'MANA', 'MATIC', 'MINA', 'MKR', 'MOB', 'MX', 'NEAR', 'NEO', 'NEXO', 'OCEAN', 'OKB', 'ONE', 'ONT', 'OSMO', 'PAXG', 'QNT', 'QTUM', 'RNDR', 'ROSE', 'RPL', 'RSR', 'RUNE', 'RVN', 'SAND', 'SC', 'SHIB', 'SKL', 'SNX', 'SOL', 'SSV', 'STORJ', 'STX', 'SUSHI', 'SXP', 'T', 'TFUEL', 'THETA', 'TRX', 'TUSD', 'TWT', 'UMA', 'UNI', 'USDC', 'USDD', 'USDT', 'VET', 'WAVES', 'WAXP', 'WBTC', 'WOO', 'XCH', 'XDC', 'XEC', 'XEM', 'XLM', 'XMR', 'XRP', 'XTZ', 'YFI', 'ZEC', 'ZEN', 'ZIL']
df_names = ['df_1inch', 'df_aave', 'df_abbc', 'df_ach', 'df_ada', 'df_algo', 'df_ankr', 'df_ape', 'df_ar', 'df_astr', 'df_atom', 'df_audio', 'df_avax', 'df_axs', 'df_bat', 'df_bch', 'df_bico', 'df_bnb', 'df_bnx', 'df_bora', 'df_bsv', 'df_btc', 'df_btg', 'df_btt', 'df_busd', 'df_cake', 'df_celo', 'df_celr', 'df_cfx', 'df_chz', 'df_ckb', 'df_comp', 'df_cro', 'df_crv', 'df_cspr', 'df_ctsi', 'df_cvx', 'df_dai', 'df_dao', 'df_dash', 'df_dcr', 'df_dgb', 'df_doge', 'df_dot', 'df_dydx', 'df_egld', 'df_elf', 'df_elon', 'df_enj', 'df_ens', 'df_eos', 'df_etc', 'df_eth', 'df_ethw', 'df_ever', 'df_fet', 'df_fil', 'df_flow', 'df_flux', 'df_ftm', 'df_fxs', 'df_gala', 'df_glm', 'df_glmr', 'df_gmt', 'df_gno', 'df_grt', 'df_gt', 'df_gusd', 'df_hbar', 'df_hive', 'df_hnt', 'df_hot', 'df_ht', 'df_icp', 'df_icx', 'df_ilv', 'df_imx', 'df_inj', 'df_iost', 'df_iotx', 'df_joe', 'df_jst', 'df_kava', 'df_kcs', 'df_kda', 'df_klay', 'df_knc', 'df_ksm', 'df_ldo', 'df_leo', 'df_link', 'df_lpt', 'df_lqty', 'df_lrc', 'df_ltc', 'df_mana', 'df_matic', 'df_mina', 'df_mkr', 'df_mob', 'df_mx', 'df_near', 'df_neo', 'df_nexo', 'df_ocean', 'df_okb', 'df_one', 'df_ont', 'df_osmo', 'df_paxg', 'df_qnt', 'df_qtum', 'df_rndr', 'df_rose', 'df_rpl', 'df_rsr', 'df_rune', 'df_rvn', 'df_sand', 'df_sc', 'df_shib', 'df_skl', 'df_snx', 'df_sol', 'df_ssv', 'df_storj', 'df_stx', 'df_sushi', 'df_sxp', 'df_t', 'df_tfuel', 'df_theta', 'df_trx', 'df_tusd', 'df_twt', 'df_uma', 'df_uni', 'df_usdc', 'df_usdd', 'df_usdt', 'df_vet', 'df_waves', 'df_waxp', 'df_wbtc', 'df_woo', 'df_xch', 'df_xdc', 'df_xec', 'df_xem', 'df_xlm', 'df_xmr', 'df_xrp', 'df_xtz', 'df_yfi', 'df_zec', 'df_zen', 'df_zil']
dfs = {}
for file_name, df_name in zip(file_list, df_names):    
    file_path = r"C:\Users\Rana\Desktop\ETD NTT\ejercicios\aa\cripto posta\{}.csv".format(file_name)
    dfs[df_name] = pd.read_csv(file_path, sep=",")
    df = dfs[df_name]
    df['+-%'] = ((df['close'] - df['open']) / df['open']) * 100
    df['+-%'] = df['+-%'].round(2)
    df['subio o bajo'] = np.where(df['close'] > df['open'], 1, -1)
    df['date'] = pd.to_datetime(df['date'])
    globals()[df_name] = df.copy()

# %%
import pandas as pd
import numpy as np

nombre_crypto = "ETH"
# Ruta del archivo CSV con el valor de nombre_crypto
ruta_archivo = r'C:\Users\Rana\Desktop\ETD NTT\ejercicios\aa\cripto posta\{}.csv'.format(nombre_crypto)

# Importar el archivo CSV y crear el DataFrame
df_nombre_crypto = pd.read_csv(ruta_archivo)

# Realizar las modificaciones en el DataFrame
df_nombre_crypto['+-%'] = ((df_nombre_crypto['close'] - df_nombre_crypto['open']) / df_nombre_crypto['open']) * 100
df_nombre_crypto['+-%'] = df_nombre_crypto['+-%'].round(2)
df_nombre_crypto['subio o bajo'] = np.where(df_nombre_crypto['close'] > df_nombre_crypto['open'], 1, -1)
df_nombre_crypto['date'] = pd.to_datetime(df_nombre_crypto['date'])

# Renombrar el DataFrame
nombre_df = "df_" + nombre_crypto.lower()
globals()[nombre_df] = df_nombre_crypto

# %%
df_eth
# Out:
#      ticker       date     open     high        low    close    +-%  \
# 0       ETH 2015-08-07     3.00     3.00     3.0000     3.00   0.00
# 1       ETH 2015-08-08     3.00     3.00     1.2000     1.20 -60.00
# 2       ETH 2015-08-09     1.20     1.20     1.2000     1.20   0.00
# 3       ETH 2015-08-10     1.20     1.20     1.2000     1.20   0.00
# 4       ETH 2015-08-11     1.20     1.20     0.6504     0.99 -17.50
# ...     ...        ...      ...      ...        ...      ...    ...
# 2868    ETH 2023-06-14  1738.98  1749.85  1630.4600  1654.07  -4.88
# 2869    ETH 2023-06-15  1653.33  1678.35  1621.2800  1665.42   0.73
# 2870    ETH 2023-06-16  1665.43  1727.80  1647.7600  1715.77   3.02
# 2871    ETH 2023-06-17  1716.62  1768.63  1713.1600  1727.64   0.64
# 2872    ETH 2023-06-18  1727.64  1747.11  1720.2600  1724.13  -0.20
#
#       subio o bajo
# 0               -1
# 1               -1
# 2               -1
# 3               -1
# 4               -1
# ...            ...
# 2868            -1
# 2869             1
# 2870             1
# 2871             1
# 2872            -1
#
# [2873 rows x 8 columns]

# %% [markdown]
# VERSION 1

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

df_eth['date'] = pd.to_datetime(df_eth['date'])
df_eth.sort_values('date', inplace=True)
data = df_eth[['open', 'high', 'low', 'close']].values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 30
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(seq_length, 4)))
model.add(Dense(4))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=10, batch_size=32)

train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

last_sequence = np.expand_dims(test_data[-seq_length:], axis=0)
next_day_prediction = model.predict(last_sequence)
next_day_prediction = scaler.inverse_transform(next_day_prediction)[0]

fecha_prediccion = df_eth['date'].values[-1] + pd.DateOffset(days=1)
abre_prediccion = next_day_prediction[0]
max_prediccion = next_day_prediction[1]
min_prediccion = next_day_prediction[2]
cierra_prediccion = next_day_prediction[3]

percentage_change = (cierra_prediccion - abre_prediccion) / abre_prediccion * 100

# Calcular R2 para los conjuntos de entrenamiento y prueba
train_r2 = r2_score(y_train, train_predictions)
test_r2 = r2_score(y_test, test_predictions)

print("Fecha del día predicho:", fecha_prediccion.date())
print("Apertura:", abre_prediccion)
print("Máximo:", max_prediccion)
print("Mínimo:", min_prediccion)
print("Cierre:", cierra_prediccion)
print("Porcentaje de cambio del precio a lo largo del día:", percentage_change)
print("Valor con mayor precisión:", ['Máximo', 'Mínimo', 'Cierre'][np.argmax(np.abs(next_day_prediction - test_data[-1]))])
print("Evaluación del modelo LSTM:")
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
print("Train R2 Score:", train_r2)
print("Test R2 Score:", test_r2)

# %% [markdown]
# vERSION 2

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

df_btc['date'] = pd.to_datetime(df_btc['date'])
df_btc.sort_values('date', inplace=True)
data = df_btc[['open', 'high', 'low', 'close']].values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 45
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(seq_length, 4)))
model.add(Dense(4))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=10, batch_size=32)

train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

last_sequence = np.expand_dims(test_data[-seq_length:], axis=0)
next_day_prediction = model.predict(last_sequence)
next_day_prediction = scaler.inverse_transform(next_day_prediction)[0]

fecha_prediccion = df_btc['date'].values[-1] + pd.DateOffset(days=1)
abre_prediccion = next_day_prediction[0]
max_prediccion = next_day_prediction[1]
min_prediccion = next_day_prediction[2]
cierra_prediccion = next_day_prediction[3]

percentage_change = (cierra_prediccion - abre_prediccion) / abre_prediccion * 100

# Calcular R2 para los conjuntos de entrenamiento y prueba
train_r2 = r2_score(y_train, train_predictions)
test_r2 = r2_score(y_test, test_predictions)

print("Fecha del día predicho:", fecha_prediccion.date())
print("Apertura:", abre_prediccion)
print("Máximo:", max_prediccion)
print("Mínimo:", min_prediccion)
print("Cierre:", cierra_prediccion)
print("Porcentaje de cambio del precio a lo largo del día:", percentage_change)
print("Evaluación del modelo LSTM:")
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
print("Train R2 Score:", train_r2)
print("Test R2 Score:", test_r2)
# Out:
# Epoch 1/10
# 117/117 [==============================] - 10s 30ms/step - loss: 7.2334e-04
# Epoch 2/10
# 117/117 [==============================] - 4s 35ms/step - loss: 3.4448e-05
# Epoch 3/10
# 117/117 [==============================] - 4s 33ms/step - loss: 3.2257e-05
# Epoch 4/10
# 117/117 [==============================] - 4s 30ms/step - loss: 3.1170e-05
# Epoch 5/10
# 117/117 [==============================] - 4s 31ms/step - loss: 2.6393e-05
# Epoch 6/10
# 117/117 [==============================] - 4s 34ms/step - loss: 2.6309e-05
# Epoch 7/10
# 117/117 [==============================] - 4s 35ms/step - loss: 2.3514e-05
# Epoch 8/10
# 117/117 [==============================] - 4s 31ms/step - loss: 2.1941e-05
# Epoch 9/10
# 117/117 [==============================] - 4s 31ms/step - loss: 2.0257e-05
# Epoch 10/10
# 117/117 [==============================] - 4s 34ms/step - loss: 2.0947e-05
# 117/117 [==============================] - 2s 12ms/step
# 29/29 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 77ms/step
# Fecha del día predicho: 2023-06-19
# Apertura: 25416.486
# Máximo: 26720.805
# Mínimo: 23216.451
# Cierre: 25616.213
# Porcentaje de cambio del precio a lo largo del día: 0.7858149707317352
# Evaluación del modelo LSTM:
# Train Loss: 1.991297358472366e-05
# Test Loss: 0.005342951975762844
# Train R2 Score: -6876511310.775757
# Test R2 Score: -32056220872.520283

# %% [markdown]
# VERSION 3

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

df_algo['date'] = pd.to_datetime(df_algo['date'])
df_algo.sort_values('date', inplace=True)
data = df_algo[['open', 'high', 'low', 'close']].values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data)-seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 90
X_train, y_train = create_sequences(train_data, seq_length)
X_test, y_test = create_sequences(test_data, seq_length)

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(seq_length, 4)))
model.add(Dense(4))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=10, batch_size=32)

train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)

train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

train_predictions = scaler.inverse_transform(train_predictions)
test_predictions = scaler.inverse_transform(test_predictions)

last_sequence = np.expand_dims(test_data[-seq_length:], axis=0)
next_day_prediction = model.predict(last_sequence)
next_day_prediction = scaler.inverse_transform(next_day_prediction)[0]

fecha_prediccion = df_algo['date'].values[-1] + pd.DateOffset(days=1)
abre_prediccion = next_day_prediction[0]
max_prediccion = next_day_prediction[1]
min_prediccion = next_day_prediction[2]
cierra_prediccion = next_day_prediction[3]

percentage_change = (cierra_prediccion - abre_prediccion) / abre_prediccion * 100

# Calcular R2 para los conjuntos de entrenamiento y prueba
train_r2 = r2_score(y_train, train_predictions)
test_r2 = r2_score(y_test, test_predictions)

print("Porcentaje de cambio del precio a lo largo del día:", percentage_change)
print("Fecha del día predicho:", fecha_prediccion.date())
print("Apertura:", abre_prediccion)
print("Máximo:", max_prediccion)
print("Mínimo:", min_prediccion)
print("Cierre:", cierra_prediccion)
print("Evaluación del modelo LSTM:")
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
print("Train R2 Score:", train_r2)
print("Test R2 Score:", test_r2)

# %%
df_btc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Usar el DataFrame df_btc existente

# Convertir la columna 'date' a formato de fecha
df_btc['date'] = pd.to_datetime(df_btc['date'])

# Establecer la columna 'date' como índice del DataFrame
df_btc.set_index('date', inplace=True)

# Crear una serie temporal para el valor de cierre
time_series = df_btc['close']

# Dividir los datos en conjunto de entrenamiento y prueba
train_data = time_series[:int(0.8 * len(time_series))]
test_data = time_series[int(0.8 * len(time_series)):]

# Entrenar el modelo ARIMA
model = ARIMA(train_data, order=(1, 0, 0))
model_fit = model.fit()

# Realizar predicciones en el conjunto de prueba
predictions = model_fit.predict(start=len(train_data), end=len(time_series)-1)

# Calcular el coeficiente de determinación (R²)
r2 = r2_score(test_data, predictions)
print("Coeficiente de determinación (R²):", r2)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(test_data, predictions)
print("Error cuadrático medio (MSE):", mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(test_data, predictions)
print("Error absoluto medio (MAE):", mae)

# Graficar las predicciones y los valores reales
plt.plot(test_data.index, test_data.values, label='Valores reales')
plt.plot(predictions.index, predictions.values, label='Predicciones')
plt.xlabel('Fecha')
plt.ylabel('Valor de cierre')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Usar el DataFrame df_btc existente

# Convertir la columna 'date' a formato de fecha
df_btc['date'] = pd.to_datetime(df_btc['date'])

# Establecer la columna 'date' como índice del DataFrame
df_btc.set_index('date', inplace=True)

# Crear una serie temporal para el valor de cierre
time_series = df_btc['close'].values.reshape(-1, 1)

# Normalizar los datos entre 0 y 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(time_series)

# Dividir los datos en conjunto de entrenamiento y prueba
train_data = scaled_data[:int(0.8 * len(scaled_data))]
test_data = scaled_data[int(0.8 * len(scaled_data)):]

# Crear secuencias de entrada y salida para el modelo LSTM
def create_sequences(data, sequence_length):
    X, y = [], []
    for i in range(len(data) - sequence_length):
        X.append(data[i:i+sequence_length])
        y.append(data[i+sequence_length])
    return np.array(X), np.array(y)

sequence_length = 7  # Longitud de la secuencia de entrada
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# Construir el modelo LSTM
model = Sequential()
model.add(LSTM(units=64, input_shape=(sequence_length, 1)))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo LSTM
model.fit(X_train, y_train, epochs=50, batch_size=32)

# Realizar predicciones en el conjunto de prueba
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)

# Invertir la normalización en los datos de prueba
y_test = scaler.inverse_transform(y_test)

# Calcular el coeficiente de determinación (R²)
r2 = r2_score(y_test, predictions)
print("Coeficiente de determinación (R²):", r2)

# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(y_test, predictions)
print("Error cuadrático medio (MSE):", mse)

# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(y_test, predictions)
print("Error absoluto medio (MAE):", mae)

# Graficar las predicciones y los valores reales
plt.plot(df_btc.index[int(0.8 * len(df_btc)) + sequence_length:], y_test, label='Valores reales')
plt.plot(df_btc.index[int(0.8 * len(df_btc)) + sequence_length:], predictions, label='Predicciones')
plt.xlabel('Fecha')
plt.ylabel('Valor de cierre')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 118/118 [==============================] - 5s 7ms/step - loss: 5.9500e-04
# Epoch 2/50
# 118/118 [==============================] - 1s 7ms/step - loss: 3.9164e-05
# Epoch 3/50
# 118/118 [==============================] - 1s 7ms/step - loss: 4.0630e-05
# Epoch 4/50
# 118/118 [==============================] - 1s 8ms/step - loss: 3.7980e-05
# Epoch 5/50
# 118/118 [==============================] - 1s 8ms/step - loss: 3.6935e-05
# Epoch 6/50
# 118/118 [==============================] - 1s 8ms/step - loss: 3.8895e-05
# Epoch 7/50
# 118/118 [==============================] - 1s 8ms/step - loss: 3.3846e-05
# Epoch 8/50
# 118/118 [==============================] - 1s 9ms/step - loss: 3.3829e-05
# Epoch 9/50
# 118/118 [==============================] - 1s 11ms/step - loss: 3.3511e-05
# Epoch 10/50
# 118/118 [==============================] - 1s 10ms/step - loss: 3.0195e-05
# Epoch 11/50
# 118/118 [==============================] - 1s 10ms/step - loss: 2.9108e-05
# Epoch 12/50
# 118/118 [==============================] - 1s 10ms/step - loss: 2.7796e-05
# Epoch 13/50
# 118/118 [==============================] - 1s 12ms/step - loss: 2.7948e-05
# Epoch 14/50
# 118/118 [==============================] - 1s 11ms/step - loss: 2.7340e-05
# Epoch 15/50
# 118/118 [==============================] - 1s 11ms/step - loss: 2.6698e-05
# Epoch 16/50
# 118/118 [==============================] - 1s 11ms/step - loss: 2.4462e-05
# Epoch 17/50
# 118/118 [==============================] - 1s 10ms/step - loss: 2.4435e-05
# Epoch 18/50
# 118/118 [==============================] - 1s 10ms/step - loss: 2.1595e-05
# Epoch 19/50
# 118/118 [==============================] - 1s 8ms/step - loss: 2.1907e-05
# Epoch 20/50
# 118/118 [==============================] - 1s 9ms/step - loss: 2.4424e-05
# Epoch 21/50
# 118/118 [==============================] - 1s 8ms/step - loss: 2.0060e-05
# Epoch 22/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.9741e-05
# Epoch 23/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.8224e-05
# Epoch 24/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.9606e-05
# Epoch 25/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.7580e-05
# Epoch 26/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.7571e-05
# Epoch 27/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.7500e-05
# Epoch 28/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.6872e-05
# Epoch 29/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.7446e-05
# Epoch 30/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.6160e-05
# Epoch 31/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.5708e-05
# Epoch 32/50
# 118/118 [==============================] - 1s 11ms/step - loss: 1.5706e-05
# Epoch 33/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.4713e-05
# Epoch 34/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.6037e-05
# Epoch 35/50
# 118/118 [==============================] - 1s 11ms/step - loss: 1.5393e-05
# Epoch 36/50
# 118/118 [==============================] - 1s 11ms/step - loss: 1.4665e-05
# Epoch 37/50
# 118/118 [==============================] - 1s 10ms/step - loss: 1.3782e-05
# Epoch 38/50
# 118/118 [==============================] - 1s 11ms/step - loss: 1.3882e-05
# Epoch 39/50
# 118/118 [==============================] - 1s 10ms/step - loss: 1.3130e-05
# Epoch 40/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.4246e-05
# Epoch 41/50
# 118/118 [==============================] - 1s 10ms/step - loss: 1.4041e-05
# Epoch 42/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.3228e-05
# Epoch 43/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.2817e-05
# Epoch 44/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.3225e-05
# Epoch 45/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.2390e-05
# Epoch 46/50
# 118/118 [==============================] - 1s 9ms/step - loss: 1.2065e-05
# Epoch 47/50
# 118/118 [==============================] - 1s 8ms/step - loss: 1.1980e-05
# Epoch 48/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2075e-05
# Epoch 49/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2033e-05
# Epoch 50/50
# 118/118 [==============================] - 1s 7ms/step - loss: 1.2463e-05
# 30/30 [==============================] - 1s 3ms/step
# Coeficiente de determinación (R²): 0.9862283811717976
# Error cuadrático medio (MSE): 2529372.1677597323
# Error absoluto medio (MAE): 1113.5572288553897

# %%
# Obtener los últimos 10 días
ultimos_10_dias = df_btc.index[-10:]

# Filtrar los datos correspondientes a los últimos 10 días
valores_reales = y_test[-10:]
predicciones = predictions[-10:]

# Graficar los últimos 10 días
plt.plot(ultimos_10_dias, valores_reales, label='Valores reales')
plt.plot(ultimos_10_dias, predicciones, label='Predicciones')
plt.xlabel('Fecha')
plt.ylabel('Valor de cierre')
plt.legend()
plt.show()
